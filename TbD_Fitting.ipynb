# %%
##This is for HF TC parameter caluclation
## Sung Chung

import scipy as sp
import numpy as np
from numpy import linspace,exp
import matplotlib.pyplot as plt
import pandas as pd
import math
from pandas.tools.plotting import andrews_curves
from scipy import interpolate
#%matplotlib inline
pd.options.display.max_columns = 100


peakAtNativeFld=-1        # if HF peak is at negative field +1, or -1(Tbd HF is -1)  
num_dev=0
absMaxFld=13900            #****may need to slightly cut end of the testing field
fltLeft=-3000*peakAtNativeFld
fltRight=4000*peakAtNativeFld
##################
directory= "C:\python"
filename='y5ghmc12sd 51-100_result_Norm'
####################
filepath=directory+"\\"+filename+".csv"
#____________________________________
DataFile=filename + "_DataTable.csv"
sumName=filename + "_Summary.csv"
sumf=directory+"\\"+sumName
dataf=directory+"\\"+DataFile

dfb=pd.read_csv(filepath,index_col = [0]).transpose()   #Add index_col = [0] to not have index values as own row during transposition
dfb=dfb.dropna()

volt=[1.9,2,2.1,2.2,2.3,2.4,2.5,2.55,2.6,2.65,2.7,2.75,2.8,2.85,2.9,2.95,3,3.05,3.1,3.15,3.2,3.25,3.3,3.35,3.4]
dfb['V']=volt


dfb.tail()
# Out:
# HD\Step(V)   51.Y5GHHP1Z  52.Y5GHHP12  53.Y5GHHP13  54.Y5GHHP14  55.Y5GHGP1A  \
# 3.20(V)         0.848428     0.990755     0.943997     0.966204     0.875741
# 3.25(V)         0.733226     0.992273     0.975440     0.883196     0.886232
# 3.30(V)         0.782452     0.988280     0.945719     0.928311     0.963675
# 3.35(V)         0.972839     1.000000     0.949849     0.917417     0.966191
# 3.40(V)         1.000000     0.970150     1.000000     0.888349     1.000000
#
# HD\Step(V)   56.Y5GHGP1B  57.Y5GHGP1K  58.Y5GHGP1D  59.Y5GHGP1E  60.Y5GHGP1F  \
# 3.20(V)         0.935689     0.947937     0.736263     0.884863     0.740204
# 3.25(V)         0.995940     0.998158     0.883416     0.927884     0.827863
# 3.30(V)         1.000000     0.949142     0.941290     1.000000     0.875399
# 3.35(V)         0.990298     0.965560     1.000000     0.961995     0.986741
# 3.40(V)         0.966469     1.000000     0.986008     0.986257     1.000000
#
# HD\Step(V)   61.Y5GHHP1E  62.Y5GHCP4Z  63.Y5GHCP4Y  64.Y5GHCP4X  65.Y5GHCP4W  \
# 3.20(V)         1.000000     0.825125     0.869465     0.897557     0.954856
# 3.25(V)         0.758257     0.915656     0.882831     0.909738     0.976235
# 3.30(V)         0.803094     0.910635     0.978332     0.992053     0.986952
# 3.35(V)         0.863146     0.933805     0.929151     0.985934     0.994080
# 3.40(V)         0.821223     1.000000     0.943415     1.000000     1.000000
#
# HD\Step(V)   66.Y5GHHP1U  67.Y5GHHP1V  68.Y5GHHP1W  69.Y5GHHP1X  70.Y5GHHP1Y  \
# 3.20(V)         0.989155     0.976138     0.744022     0.996008     0.964263
# 3.25(V)         0.979492     0.974104     0.800137     1.000000     0.975803
# 3.30(V)         0.972391     0.982068     0.860711     0.994469     0.941736
# 3.35(V)         0.994212     1.000000     1.000000     0.994118     0.993712
# 3.40(V)         0.994877     0.973924     0.979498     0.969632     0.985680
#
# HD\Step(V)   71.Y5GHHP1S  72.Y5GHHP1R  73.Y5GHHP1P  74.Y5GHHP1N  75.Y5GHHP1M  \
# 3.20(V)         0.911179     0.840966     0.869123     0.880772     0.734017
# 3.25(V)         1.000000     0.999116     0.768366     0.801284     0.736463
# 3.30(V)         0.995359     0.946640     0.894838     0.909383     0.800523
# 3.35(V)         0.906611     1.000000     0.940699     0.945342     0.828035
# 3.40(V)         0.890096     0.971726     1.000000     1.000000     1.000000
#
# HD\Step(V)   76.Y5GHHP1K  77.Y5GHHP1J  78.Y5GHHP1H  79.Y5GHHP1G  80.Y5GHHP1F  \
# 3.20(V)         0.450697     0.896268     0.937068     0.925693     0.956474
# 3.25(V)         0.352210     0.924020     0.958550     0.896756     0.909272
# 3.30(V)         0.503604     0.980516     0.973534     0.929520     0.921564
# 3.35(V)         1.000000     1.000000     0.990138     0.967383     0.910021
# 3.40(V)         0.583043     0.989562     1.000000     1.000000     1.000000
#
# HD\Step(V)   81.Y5GHDP33  82.Y5GHDP3S  83.Y5GHCP3T  84.Y5GHCP3U  85.Y5GHCP3V  \
# 3.20(V)         0.857409     0.944857     0.997267     0.229099     0.958423
# 3.25(V)         0.923665     1.000000     0.993827     0.356561     0.962620
# 3.30(V)         0.953058     0.965790     0.931561     0.970971     0.929515
# 3.35(V)         1.000000     0.946621     0.962551     1.000000     0.926311
# 3.40(V)         0.998314     0.958203     0.956649     0.978544     0.988423
#
# HD\Step(V)   86.Y5GHCP3W  87.Y5GHCP3X  88.Y5GHCP3Y  89.Y5GHCP3Z  90.Y5GHDP4E  \
# 3.20(V)         1.000000     0.402297     0.966771     0.816212     0.879165
# 3.25(V)         0.981151     0.936053     0.978454     1.000000     0.975053
# 3.30(V)         0.947179     0.932911     0.981765     0.956014     1.000000
# 3.35(V)         0.936519     0.987174     0.986336     0.949810     0.997204
# 3.40(V)         0.989526     1.000000     1.000000     0.940464     0.993361
#
# HD\Step(V)   91.Y5GHCP3J  92.Y5GHCP3H  93.Y5GHCP3G  94.Y5GHCP3T  95.Y5GHCP3E  \
# 3.20(V)         0.525664     0.649214     0.801541     0.989877     0.521672
# 3.25(V)         0.552604     0.724530     0.842125     0.942283     0.484436
# 3.30(V)         0.641101     0.773763     0.825728     0.967778     0.940780
# 3.35(V)         1.000000     0.966903     0.928712     0.974181     0.973024
# 3.40(V)         0.983841     1.000000     1.000000     1.000000     1.000000
#
# HD\Step(V)   96.Y5GHCP3D  97.Y5GHCP3C  98.Y5GHCP3B  99.Y5GHCP3A  100.Y5GHDP34  \
# 3.20(V)         0.998459     0.690303     0.958868     0.987972      0.936839
# 3.25(V)         0.974616     0.702356     0.967076     0.997052      0.917823
# 3.30(V)         0.928485     0.733291     0.971085     0.991756      0.942914
# 3.35(V)         0.914039     0.785377     1.000000     1.000000      1.000000
# 3.40(V)         0.980911     1.000000     0.987271     0.989947      0.957029
#
# HD\Step(V)      V
# 3.20(V)      3.20
# 3.25(V)      3.25
# 3.30(V)      3.30
# 3.35(V)      3.35
# 3.40(V)      3.40

# %%
fitDeg=4
outName=filename + "_Fitdeg_"+ str(fitDeg)+".csv"
print outName
# Out:
# y5ghmc12sd 51-100_result_Norm_Fitdeg_4.csv

# %%
fitDeg=6
outName=filename + "_Fitdeg_"+ str(fitDeg)+".csv"
outputF=directory+"\\"+outName

colName=dfb.columns.values
devN=[]
crtV=[]
PartID=[]

testedN=dfb.columns.size-1

for i in range(0,testedN):
    PartID.append(colName[i])    
    
    x1=dfb.loc[:,"V"]
    y1=dfb.iloc[:,i]   
    
    fp=sp.polyfit(x1,y1,4)
    f=sp.poly1d(fp)
    plt.plot(x1,y1,'o',x1,f(x1))
    
    
    fphalf=sp.polyfit(x1,y1-0.5,fitDeg)
    fhalf=sp.poly1d(fphalf)
    
    
    
    roots=np.roots(fhalf)
#     dev[i-1]=i
    
    for k in roots:
        if ((k.real>1.9 and k.real<3.4) and k.imag==0):
            devN.append(i)
            crtV.append(k.real)


dfT=pd.DataFrame({"devN":devN, "Critical Voltage(V)":crtV,'Fitdeg':fitDeg, "PartID":PartID })
dfT.head()
dfT.to_csv(outputF)
    

plt.title(outName)
plt.axhline(y=0.5, color='r', linestyle='-')
plt.show()
